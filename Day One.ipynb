# %%
print("Hello World")
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
print(5.6)
# Out:
# 5.6

# %%
print(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(false)
#
# NameError: name 'false' is not defined

# %%
print(False)
# Out:
# False

# %%
print("india","pakistan","afganistan",5)
# Out:
# india pakistan afganistan 5

# %%
print()

# %%
print("india","pakistan","afganistan",sep='/')
# Out:
# india/pakistan/afganistan

# %%
print("india","pakistan","afganistan",sep='-')
# Out:
# india-pakistan-afganistan

# %%
print("india","pakistan","afganistan",sep='=')
# Out:
# india=pakistan=afganistan

# %%
print("india","pakistan","afganistan",end=' ')
print("india","pakistan","afganistan",sep='-')
# Out:
# india pakistan afganistan india-pakistan-afganistan
