# %%
input()
# Out:
#  56
# '56'

# %%
input('Apna naam batao')
# Out:
# Apna naam batao abdul kaiyum
# 'abdul kaiyum'

# %%
firstnumber = input("enter the first number")
secondnumber = input("enter the second number")
# Out:
# enter the first number 56
# enter the second number 76

# %%
print(firstnumber)
# Out:
# 56

# %%
print(secondnumber)
# Out:
# 76

# %%
result = firstnumber + secondnumber

# %%
print(result)
# Out:
# 5676

# %%
#type
type(4)
# Out:
# int

# %%
#type
type(4.5)
# Out:
# float

# %%
#type
type(abdulkaiyum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #type
# ----> 2 type(abdulkaiyum)
#
# NameError: name 'abdulkaiyum' is not defined

# %%
#type
type([1,2,3,4,5,6])
# Out:
# list

# %%
type(firstnumber)
# Out:
# str

# %%
firstnumber
# Out:
# '56'
