# %%
# correct = ug2102059@cse.pstu.ac.bd
# password = 123456

email = input("Input your email")
password = input("Input your password")

if email == "ug2102059@cse.pstu.ac.bd" and password == "123456" :
    print ("Welcome")

else:
    print ("Incorrect Credentials")
# Out:
# Input your email ug2102059@cse.pstu.ac.bd
# Input your password 123456
# Welcome

# %%
# correct = ug2102059@cse.pstu.ac.bd
# password = 123456

email = input("Input your email")
if '@'in email :
          # correct = ug2102059@cse.pstu.ac.bd
        # password = 123456
        
        email = input("Input your email")
        password = input("Input your password")
        
        if email == "ug2102059@cse.pstu.ac.bd" and password == "123456" :
            print ("Welcome")
        
        elif email == "ug2102059@cse.pstu.ac.bd" and password != "123456" :
            print ("Password Incorrect")
            password = input("Input password again")
        
            if  password =="123456" :
                print("Finally Correct")
        
            else:
                   print(" Still Incorrect ")
        
        else:
            print ("Incorrect Credentials")
else:
    print("Your email is not correct")
# Out:
# Input your email dfghlkdsgh
# Your email is not correct
