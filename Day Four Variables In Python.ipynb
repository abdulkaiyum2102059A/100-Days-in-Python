# %%
#c 
# int a = 5

# %%
name ="kaiyum"

# %%
print(name)
# Out:
# kaiyum

# %%
name = "hello world"
print(name)
# Out:
# hello world

# %%
# no variable detection that means here it is not required to write the data type of the variable

# %%
# in static data typing it is required to write the data type

# %%
name= 5

# %%
print(name )
# Out:
# 5

# %%
name = True

# %%
print(name)
# Out:
# True

# %%
#multiple variable syntax
a=4;b=5;c=6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a,b,c=4,5,6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a=b=c=4
print(a)
print(b)
print(c)
# Out:
# 4
# 4
# 4
